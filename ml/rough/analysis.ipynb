# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('dark_background')

# %%
df = pd.read_excel('../data/Finance.xlsx' , skiprows=1)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Month  LUMPSUM  SIP AMOUNT  STEP-UP  \
# 0         NaN         NaN         NaN      1  5000000  20000.0000     0.01
# 1         NaN         NaN         NaN      2        0  20200.0000     0.01
# 2         NaN         NaN         NaN      3        0  20402.0000     0.01
# 3         NaN         NaN         NaN      4        0  20606.0200     0.01
# 4         NaN         NaN         NaN      5        0  20812.0802     0.01
#
#    RUNNING LUMPSUMP  EXPECTED RETURN  INVESTED AMOUNT  MARKET VALUE
# 0                 0             0.12       20000.0000   5070200.000
# 1                 0             0.12       40200.0000   5141304.000
# 2                 0             0.12       60602.0000   5213323.060
# 3                 0             0.12       81208.0200   5286268.371
# 4                 0             0.12      102020.1002   5360151.256

# %%
df = df.iloc[: , 3:]
df.columns
# Out:
# Index(['Month', 'LUMPSUM', 'SIP AMOUNT', 'STEP-UP', 'RUNNING LUMPSUMP',
#        'EXPECTED RETURN', 'INVESTED AMOUNT', 'MARKET VALUE'],
#       dtype='object')

# %%
df['Month']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 405    406
# 406    407
# 407    408
# 408    409
# 409    410
# Name: Month, Length: 410, dtype: int64

# %%
sns.lineplot(df , x = 'Month' , y = 'MARKET VALUE')
# Out:
# <Axes: xlabel='Month', ylabel='MARKET VALUE'>
