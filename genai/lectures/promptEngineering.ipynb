# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import getpass

plt.rcParams['axes.prop_cycle'] = plt.cycler(color = sns.color_palette('dark'))
plt.style.use('dark_background')
plt.rcParams['figure.figsize'] = (10 , 8)

# %%
# web search tool using ddgs:
import ddgs

def web_search(query):
    with ddgs.DDGS() as searcher:
        result = list(searcher.text(query , max_results = 2))
        return result
    
web_search('Iran, Ayatulha Khaumini')
# Out:
# [{'title': 'Regime Change Riots In Iran Fail Faster Than Expected – Moon of...',
#   'href': 'https://www.moonofalabama.org/2026/01/regime-change-riots-in-iran-fail-faster-than-expected.html',
#   'body': 'The Iranian government did not bother to track down single terminals but used the new Russian and Chinese equipment to shut down all Starlink traffic in Iran .'},
#  {'title': 'Iran Says It Is Prepared for War but Ready to Negotiate After...',
#   'href': 'https://www.nytimes.com/2026/01/12/world/middleeast/iran-protests-trump-us.html',
#   'body': 'Iran ’s foreign minister, in a short gray beard and dark suit, walking with several other men. A large building is blurred in the background.'}]
